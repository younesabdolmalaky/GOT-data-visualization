# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from bokeh.io import output_notebook
from bokeh.plotting import figure, output_file, show
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('../datasets/Game_of_Thrones.csv')
df.head(20)
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# 5        1                        6                         6
# 6        1                        7                         7
# 7        1                        8                         8
# 8        1                        9                         9
# 9        1                       10                        10
# 10       2                        1                        11
# 11       2                        2                        12
# 12       2                        3                        13
# 13       2                        4                        14
# 14       2                        5                        15
# 15       2                        6                        16
# 16       2                        7                        17
# 17       2                        8                        18
# 18       2                        9                        19
# 19       2                       10                        20
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# 2                               Lord Snow                      57
# 3   Cripples, Bastards, and Broken Things                      55
# 4                   The Wolf and the Lion                      54
# 5                          A Golden Crown                      52
# 6                      You Win or You Die                      57
# 7                          The Pointy End                      58
# 8                                  Baelor                      56
# 9                          Fire and Blood                      52
# 10                    The North Remembers                      52
# 11                        The Night Lands                      53
# 12             What Is Dead May Never Die                      52
# 13                        Garden of Bones                      50
# 14                 The Ghost of Harrenhal                      54
# 15               The Old Gods and the New                      54
# 16                    A Man Without Honor                      55
# 17               The Prince of Winterfell                      53
# 18                             Blackwater                      54
# 19                        Valar Morghulis                      63
#
#        Directed by                                 Written by  \
# 0   Tim Van Patten                 David Benioff, D. B. Weiss
# 1   Tim Van Patten                 David Benioff, D. B. Weiss
# 2       Brian Kirk                 David Benioff, D. B. Weiss
# 3       Brian Kirk                               Bryan Cogman
# 4       Brian Kirk                 David Benioff, D. B. Weiss
# 5   Daniel Minahan  Jane Espenson, David Benioff, D. B. Weiss
# 6   Daniel Minahan                 David Benioff, D. B. Weiss
# 7   Daniel Minahan                        George R. R. Martin
# 8      Alan Taylor                 David Benioff, D. B. Weiss
# 9      Alan Taylor                 David Benioff, D. B. Weiss
# 10     Alan Taylor                 David Benioff, D. B. Weiss
# 11     Alan Taylor                 David Benioff, D. B. Weiss
# 12   Alik Sakharov                               Bryan Cogman
# 13  David Petrarca                             Vanessa Taylor
# 14  David Petrarca                 David Benioff, D. B. Weiss
# 15    David Nutter                             Vanessa Taylor
# 16    David Nutter                 David Benioff, D. B. Weiss
# 17     Alan Taylor                 David Benioff, D. B. Weiss
# 18   Neil Marshall                        George R. R. Martin
# 19     Alan Taylor                 David Benioff, D. B. Weiss
#
#    Original Air Date  U.S. Viewers (Millions)       Music by  \
# 0        17-Apr-2011                     2.22  Ramin Djawadi
# 1        24-Apr-2011                     2.20  Ramin Djawadi
# 2         1-May-2011                     2.44  Ramin Djawadi
# 3         8-May-2011                     2.45  Ramin Djawadi
# 4        15-May-2011                     2.58  Ramin Djawadi
# 5        22-May-2011                     2.44  Ramin Djawadi
# 6        29-May-2011                     2.40  Ramin Djawadi
# 7         5-Jun-2011                     2.72  Ramin Djawadi
# 8        12-Jun-2011                     2.66  Ramin Djawadi
# 9        19-Jun-2011                     3.04  Ramin Djawadi
# 10        1-Apr-2012                     3.86  Ramin Djawadi
# 11        8-Apr-2012                     3.76  Ramin Djawadi
# 12       15-Apr-2012                     3.77  Ramin Djawadi
# 13       22-Apr-2012                     3.65  Ramin Djawadi
# 14       29-Apr-2012                     3.90  Ramin Djawadi
# 15        6-May-2012                     3.88  Ramin Djawadi
# 16       13-May-2012                     3.69  Ramin Djawadi
# 17       20-May-2012                     3.86  Ramin Djawadi
# 18       27-May-2012                     3.38  Ramin Djawadi
# 19        3-Jun-2012                     4.20  Ramin Djawadi
#
#     Cinematography by         Editing by  IMDb Rating  \
# 0       Alik Sakharov  Oral Norrie Ottey          8.9
# 1       Alik Sakharov  Oral Norrie Ottey          8.6
# 2    Marco Pontecorvo     Frances Parker          8.5
# 3    Marco Pontecorvo     Frances Parker          8.6
# 4    Marco Pontecorvo     Frances Parker          9.0
# 5      Matthew Jensen   Martin Nicholson          9.1
# 6      Matthew Jensen   Martin Nicholson          9.1
# 7      Matthew Jensen   Martin Nicholson          8.9
# 8       Alik Sakharov     Frances Parker          9.6
# 9       Alik Sakharov     Frances Parker          9.4
# 10  Kramer Morgenthau     Frances Parker          8.6
# 11  Kramer Morgenthau     Frances Parker          8.4
# 12        P.J. Dillon      Katie Weiland          8.7
# 13      Martin Kenzie      Katie Weiland          8.6
# 14      Martin Kenzie      Katie Weiland          8.6
# 15      Martin Kenzie  Oral Norrie Ottey          8.9
# 16      Martin Kenzie  Oral Norrie Ottey          8.8
# 17   Jonathan Freeman     Frances Parker          8.6
# 18        Sam McCurdy  Oral Norrie Ottey          9.6
# 19   Jonathan Freeman     Frances Parker          9.3
#
#     Rotten Tomatoes Rating (Percentage)  Metacritic Ratings         Ordered  \
# 0                                   100                 9.1   March 2, 2010
# 1                                   100                 8.9   March 2, 2010
# 2                                    81                 8.7   March 2, 2010
# 3                                   100                 9.1   March 2, 2010
# 4                                    95                 9.0   March 2, 2010
# 5                                   100                 9.2   March 2, 2010
# 6                                   100                 9.4   March 2, 2010
# 7                                    95                 8.9   March 2, 2010
# 8                                   100                 9.5   March 2, 2010
# 9                                   100                 9.4   March 2, 2010
# 10                                  100                 8.9  April 19, 2011
# 11                                   89                 7.7  April 19, 2011
# 12                                  100                 8.3  April 19, 2011
# 13                                   97                 9.0  April 19, 2011
# 14                                   96                 7.6  April 19, 2011
# 15                                  100                 9.3  April 19, 2011
# 16                                   96                 8.7  April 19, 2011
# 17                                  100                 8.8  April 19, 2011
# 18                                  100                 9.5  April 19, 2011
# 19                                   92                 9.2  April 19, 2011
#
#        Filming Duration   Novel(s) Adapted  \
# 0   Second half of 2010  A Game of Thrones
# 1   Second half of 2010  A Game of Thrones
# 2   Second half of 2010  A Game of Thrones
# 3   Second half of 2010  A Game of Thrones
# 4   Second half of 2010  A Game of Thrones
# 5   Second half of 2010  A Game of Thrones
# 6   Second half of 2010  A Game of Thrones
# 7   Second half of 2010  A Game of Thrones
# 8   Second half of 2010  A Game of Thrones
# 9   Second half of 2010  A Game of Thrones
# 10  Second half of 2011   A Clash of Kings
# 11  Second half of 2011   A Clash of Kings
# 12  Second half of 2011   A Clash of Kings
# 13  Second half of 2011   A Clash of Kings
# 14  Second half of 2011   A Clash of Kings
# 15  Second half of 2011   A Clash of Kings
# 16  Second half of 2011   A Clash of Kings
# 17  Second half of 2011   A Clash of Kings
# 18  Second half of 2011   A Clash of Kings
# 19  Second half of 2011   A Clash of Kings
#
#                                              Synopsis
# 0   North of the Seven Kingdoms of Westeros, Night...
# 1   Ned, the new Hand of the King, travels to King...
# 2   Ned attends the King's Small Council and learn...
# 3   While returning to King's Landing, Tyrion stop...
# 4   King Robert's eunuch spy, Varys, has uncovered...
# 5   King Robert reappoints Ned as Hand and tasks h...
# 6   In King's Landing, Ned confronts Cersei, sayin...
# 7   Arya escapes the Red Keep after Syrio Forel, h...
# 8   The Stark army arrives at the Twins castle; Ca...
# 9   The North secedes from the Seven Kingdoms and ...
# 10  In King's Landing, Tyrion becomes acting Hand ...
# 11  Returning to Pyke Island after nine years as t...
# 12  Catelyn arrives at Renly's camp to negotiate a...
# 13  Robb's Army attacks a Lannister Army at Oxcros...
# 14  At Harrenhal, Jaqen H'ghar, one of three caged...
# 15  Against Cersei's wishes, Tyrion sends her and ...
# 16  Theon and his men pursue Brandon and Rickon. T...
# 17  Robb learns that Catelyn secretly freed Jaime ...
# 18  Stannis' fleet assaults King's Landing. Sansa ...
# 19  Joffrey sets Sansa aside to marry Margaery Tyr...

# %%
Season = df['Season'].unique()

# %%
labels = ['Season '+str(i) for i in Season]

# %%
Episodes = np.array(df['Season'].value_counts())

# %%
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n".format(pct, absolute)

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(Episodes, labels = labels,autopct = lambda pct: func(pct, Episodes),
)
plt.show()

# %%
df['Rotten Tomatoes Rating (Percentage)'] = df['Rotten Tomatoes Rating (Percentage)']/10
df.head()
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
# 2       1                        3                         3
# 3       1                        4                         4
# 4       1                        5                         5
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
#
#       Directed by                  Written by Original Air Date  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2      Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3      Brian Kirk                Bryan Cogman        8-May-2011
# 4      Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
#
#    U.S. Viewers (Millions)       Music by Cinematography by  \
# 0                     2.22  Ramin Djawadi     Alik Sakharov
# 1                     2.20  Ramin Djawadi     Alik Sakharov
# 2                     2.44  Ramin Djawadi  Marco Pontecorvo
# 3                     2.45  Ramin Djawadi  Marco Pontecorvo
# 4                     2.58  Ramin Djawadi  Marco Pontecorvo
#
#           Editing by  IMDb Rating  Rotten Tomatoes Rating (Percentage)  \
# 0  Oral Norrie Ottey          8.9                                 10.0
# 1  Oral Norrie Ottey          8.6                                 10.0
# 2     Frances Parker          8.5                                  8.1
# 3     Frances Parker          8.6                                 10.0
# 4     Frances Parker          9.0                                  9.5
#
#    Metacritic Ratings        Ordered     Filming Duration   Novel(s) Adapted  \
# 0                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 1                 8.9  March 2, 2010  Second half of 2010  A Game of Thrones
# 2                 8.7  March 2, 2010  Second half of 2010  A Game of Thrones
# 3                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 4                 9.0  March 2, 2010  Second half of 2010  A Game of Thrones
#
#                                             Synopsis
# 0  North of the Seven Kingdoms of Westeros, Night...
# 1  Ned, the new Hand of the King, travels to King...
# 2  Ned attends the King's Small Council and learn...
# 3  While returning to King's Landing, Tyrion stop...
# 4  King Robert's eunuch spy, Varys, has uncovered...

# %%
df['total_score'] =df['IMDb Rating'] + df['Rotten Tomatoes Rating (Percentage)'] + df['Metacritic Ratings']

# %%
df = df.rename(columns={"No. of Episode (Season)": "Episode", "Directed by": "Director" , "Written by": "Writter" })

# %%
df.head()
# Out:
#    Season  Episode  No. of Episode (Overall)  \
# 0       1        1                         1
# 1       1        2                         2
# 2       1        3                         3
# 3       1        4                         4
# 4       1        5                         5
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
#
#          Director                     Writter Original Air Date  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2      Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3      Brian Kirk                Bryan Cogman        8-May-2011
# 4      Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
#
#    U.S. Viewers (Millions)       Music by Cinematography by  \
# 0                     2.22  Ramin Djawadi     Alik Sakharov
# 1                     2.20  Ramin Djawadi     Alik Sakharov
# 2                     2.44  Ramin Djawadi  Marco Pontecorvo
# 3                     2.45  Ramin Djawadi  Marco Pontecorvo
# 4                     2.58  Ramin Djawadi  Marco Pontecorvo
#
#           Editing by  IMDb Rating  Rotten Tomatoes Rating (Percentage)  \
# 0  Oral Norrie Ottey          8.9                                 10.0
# 1  Oral Norrie Ottey          8.6                                 10.0
# 2     Frances Parker          8.5                                  8.1
# 3     Frances Parker          8.6                                 10.0
# 4     Frances Parker          9.0                                  9.5
#
#    Metacritic Ratings        Ordered     Filming Duration   Novel(s) Adapted  \
# 0                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 1                 8.9  March 2, 2010  Second half of 2010  A Game of Thrones
# 2                 8.7  March 2, 2010  Second half of 2010  A Game of Thrones
# 3                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 4                 9.0  March 2, 2010  Second half of 2010  A Game of Thrones
#
#                                             Synopsis  total_score
# 0  North of the Seven Kingdoms of Westeros, Night...         28.0
# 1  Ned, the new Hand of the King, travels to King...         27.5
# 2  Ned attends the King's Small Council and learn...         25.3
# 3  While returning to King's Landing, Tyrion stop...         27.7
# 4  King Robert's eunuch spy, Varys, has uncovered...         27.5

# %%
dataSource = ColumnDataSource(df)

p = figure()
p.circle(source=dataSource, x='U.S. Viewers (Millions)', y='total_score', color='green' , size=20)

p.title.text = 'Popularity chart of directors episodes'
p.xaxis.axis_label = 'Viewers'
p.yaxis.axis_label = 'total score'

h = HoverTool()
h.tooltips = [
    ('Directed by', '@Director'),
    ('Written by', '@Writter'),
    ('Season', '@Season'),
    ('Episode', '@Episode')

]
p.add_tools(h)

show(p)
# Out:
#   <div id="d94aa8bb-09f4-4314-b49a-1f0e440d5ca7" data-root-id="p1005" style="display: contents;"></div>

# %%
dataGrouped = (df.groupby('Director')['total_score' , 'IMDb Rating'].mean())
dataGrouped = dataGrouped.sort_values('total_score')
# Out:
# /tmp/ipykernel_7492/2939304429.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataGrouped = (df.groupby('Director')['total_score' , 'IMDb Rating'].mean())

# %%
dataGrouped['counts'] = (df.groupby('Director')['Director'].count())

# %%
dataGrouped
# Out:
#                              total_score  IMDb Rating  counts
# Director
# David Benioff & D. B. Weiss    11.300000     4.000000       1
# Miguel Sapochnik               23.766667     8.650000       6
# Jeremy Podeswa                 23.933333     8.666667       6
# Daniel Sackheim                24.550000     8.800000       2
# Mark Mylod                     24.650000     8.600000       6
# Matt Shakman                   24.750000     9.200000       2
# David Nutter                   24.866667     8.455556       9
# Jack Bender                    24.950000     9.000000       2
# David Petrarca                 26.550000     8.600000       2
# David Benioff                  26.700000     8.700000       1
# Michael Slovis                 26.750000     8.350000       2
# Michelle MacLaren              26.800000     8.700000       4
# Alan Taylor                    26.828571     8.985714       7
# Brian Kirk                     26.833333     8.700000       3
# Daniel Minahan                 27.120000     8.840000       5
# Alik Sakharov                  27.150000     9.025000       4
# D. B. Weiss                    27.600000     9.000000       1
# Tim Van Patten                 27.750000     8.750000       2
# Alex Graves                    28.150000     9.350000       6
# Neil Marshall                  28.750000     9.600000       2

# %%
from bokeh.palettes import GnBu3, Category20
from bokeh.transform import factor_cmap
cm = factor_cmap(field_name='Director', palette=Category20[len(Directors)], factors=Directors)

# %%
dataSource = ColumnDataSource(dataGrouped)
Directors = dataSource.data['Director'].tolist()
p = figure(y_range=Directors)


p.hbar(source=dataSource, y='Director', right='total_score',left=10, height=0.5, width=4 ,color = cm)

h = HoverTool()
h.tooltips = [
    ('number of episode', '@counts')
]
p.add_tools(h)
show(p)
# Out:
#   <div id="afda769a-273a-44b1-82bc-6e1f855d9908" data-root-id="p2324" style="display: contents;"></div>

# %%
df.head()
# Out:
#    Season  Episode  No. of Episode (Overall)  \
# 0       1        1                         1
# 1       1        2                         2
# 2       1        3                         3
# 3       1        4                         4
# 4       1        5                         5
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
#
#          Director                     Writter Original Air Date  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2      Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3      Brian Kirk                Bryan Cogman        8-May-2011
# 4      Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
#
#    U.S. Viewers (Millions)       Music by Cinematography by  \
# 0                     2.22  Ramin Djawadi     Alik Sakharov
# 1                     2.20  Ramin Djawadi     Alik Sakharov
# 2                     2.44  Ramin Djawadi  Marco Pontecorvo
# 3                     2.45  Ramin Djawadi  Marco Pontecorvo
# 4                     2.58  Ramin Djawadi  Marco Pontecorvo
#
#           Editing by  IMDb Rating  Rotten Tomatoes Rating (Percentage)  \
# 0  Oral Norrie Ottey          8.9                                 10.0
# 1  Oral Norrie Ottey          8.6                                 10.0
# 2     Frances Parker          8.5                                  8.1
# 3     Frances Parker          8.6                                 10.0
# 4     Frances Parker          9.0                                  9.5
#
#    Metacritic Ratings        Ordered     Filming Duration   Novel(s) Adapted  \
# 0                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 1                 8.9  March 2, 2010  Second half of 2010  A Game of Thrones
# 2                 8.7  March 2, 2010  Second half of 2010  A Game of Thrones
# 3                 9.1  March 2, 2010  Second half of 2010  A Game of Thrones
# 4                 9.0  March 2, 2010  Second half of 2010  A Game of Thrones
#
#                                             Synopsis  total_score
# 0  North of the Seven Kingdoms of Westeros, Night...         28.0
# 1  Ned, the new Hand of the King, travels to King...         27.5
# 2  Ned attends the King's Small Council and learn...         25.3
# 3  While returning to King's Landing, Tyrion stop...         27.7
# 4  King Robert's eunuch spy, Varys, has uncovered...         27.5

# %%
data = df.groupby('Season')['total_score'].mean()
data_sorted = data.sort_values()
index = data_sorted.index
values = data_sorted
index = ['Season '+str(i) for i in index]

# %%
data_sorted = data.sort_values()

# %%
index = data_sorted.index
values = data_sorted

# %%
plt.barh(index ,values , height = 0.7 , color = 'green')
# Out:
# <BarContainer object of 8 artists>
